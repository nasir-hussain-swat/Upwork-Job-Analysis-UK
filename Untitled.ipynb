# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("upwork-jobs.csv")
df.head(1)
# Out:
#                                                title  \
# 0  Experienced Media Buyer For Solar Pannel and R...
#
#                                                 link  \
# 0  https://www.upwork.com/jobs/Experienced-Media-...
#
#                                          description  \
# 0  We’re looking for a talented and hardworking a...
#
#               published_date is_hourly  hourly_low  hourly_high  budget  \
# 0  2024-02-17 09:09:54+00:00     False         NaN          NaN   500.0
#
#   country
# 0     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53058 entries, 0 to 53057
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           53058 non-null  object
#  1   link            53058 non-null  object
#  2   description     53058 non-null  object
#  3   published_date  53058 non-null  object
#  4   is_hourly       44829 non-null  object
#  5   hourly_low      22956 non-null  float64
#  6   hourly_high     22161 non-null  float64
#  7   budget          21873 non-null  float64
#  8   country         51917 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 3.6+ MB

# %%
df.isnull().sum()
# Out:
# title                 0
# link                  0
# description           0
# published_date        0
# is_hourly          8229
# hourly_low        30102
# hourly_high       30897
# budget            31185
# country            1141
# dtype: int64

# %%
# Fill 'is_hourly' column with mode (most frequent value)
df['is_hourly'].fillna(df['is_hourly'].mode()[0], inplace=True)

# %%
# Fill 'hourly_low' column with mean
hourly_low_mean = df['hourly_low'].mean()
df['hourly_low'].fillna(hourly_low_mean, inplace=True)

# %%
# Fill 'hourly_high' column with mean
hourly_high_mean = df['hourly_high'].mean()
df['hourly_high'].fillna(hourly_high_mean, inplace=True)

# %%
# Fill 'budget' column with mean
budget_mean = df['budget'].mean()
df['budget'].fillna(budget_mean, inplace=True)

# Now the null values in the specified columns should be filled as per your requirements

# %%
df.isnull().sum()
# Out:
# title                0
# link                 0
# description          0
# published_date       0
# is_hourly            0
# hourly_low           0
# hourly_high          0
# budget               0
# country           1141
# dtype: int64

# %%
len(df)
# Out:
# 53058

# %%
df.dropna(subset=['country'], inplace=True)

# %%
len(df)
# Out:
# 51917

# %%
df.isnull().sum()
# Out:
# title             0
# link              0
# description       0
# published_date    0
# is_hourly         0
# hourly_low        0
# hourly_high       0
# budget            0
# country           0
# dtype: int64

# %%
df.head()
# Out:
#                                     title  \
# 1                    Full Stack Developer
# 2                         SMMA Bubble App
# 3  Talent Hunter Specialized in Marketing
# 4                           Data Engineer
# 5    SEO for Portuguese Psychologist site
#
#                                                 link  \
# 1  https://www.upwork.com/jobs/Full-Stack-Develop...
# 2  https://www.upwork.com/jobs/SMMA-Bubble-App_%7...
# 3  https://www.upwork.com/jobs/Talent-Hunter-Spec...
# 4  https://www.upwork.com/jobs/Data-Engineer_%7E0...
# 5  https://www.upwork.com/jobs/SEO-for-Portuguese...
#
#                                          description  \
# 1  Job Title: Full Stack DeveloperWe are seeking ...
# 2  I need someone to redesign my bubble.io site t...
# 3  Join Our Growing Team!We are an innovative com...
# 4  We are looking for a resource who can work par...
# 5  Looking for a SEO  who can help me improve my ...
#
#               published_date  is_hourly  hourly_low  hourly_high       budget  \
# 1  2024-02-17 09:09:17+00:00      False   17.467895     41.60805  1100.000000
# 2  2024-02-17 09:08:46+00:00       True   10.000000     30.00000   746.263521
# 3  2024-02-17 09:08:08+00:00       True   17.467895     41.60805   746.263521
# 4  2024-02-17 09:07:42+00:00      False   17.467895     41.60805   650.000000
# 5  2024-02-17 09:07:41+00:00       True   17.467895     41.60805   746.263521
#
#          country
# 1  United States
# 2  United States
# 3  United States
# 4          India
# 5       Portugal

# %%
#checking for SEO related jobs
df[df["title"].str.contains("SEO")]
# Out:
#                                                    title  \
# 5                   SEO for Portuguese Psychologist site
# 87     Certified personal trainer / physical therapis...
# 142    Copywriter - SEO friendly articles on tech inn...
# 167       high-end SEO friendly website for watch buyers
# 266                              Formation sur YOAST SEO
# ...                                                  ...
# 52743               Amazon FBA new product SEO JUMPSTART
# 52867        In need of SEO for Private Practice Website
# 52907             German-speaking Content Writer for SEO
# 52917  Implement SEO Strategy for Italian Shoe Brand ...
# 53018  Do A Fully SEO Focused Competitor Analysis For...
#
#                                                     link  \
# 5      https://www.upwork.com/jobs/SEO-for-Portuguese...
# 87     https://www.upwork.com/jobs/Certified-personal...
# 142    https://www.upwork.com/jobs/Copywriter-SEO-fri...
# 167    https://www.upwork.com/jobs/high-end-SEO-frien...
# 266    https://www.upwork.com/jobs/Formation-sur-YOAS...
# ...                                                  ...
# 52743  https://www.upwork.com/jobs/Amazon-FBA-new-pro...
# 52867  https://www.upwork.com/jobs/need-SEO-for-Priva...
# 52907  https://www.upwork.com/jobs/German-speaking-Co...
# 52917  https://www.upwork.com/jobs/Implement-SEO-Stra...
# 53018  https://www.upwork.com/jobs/Fully-SEO-Focused-...
#
#                                              description  \
# 5      Looking for a SEO  who can help me improve my ...
# 87     We are seeking a certified personal trainer or...
# 142    I'm seeking a talented Freelance Copywriter t,...
# 167    Project Description:We are seeking an experien...
# 266    Bonjour.Je suis à la recherche d'un formateur ...
# ...                                                  ...
# 52743  Need someone who can bring Amazon store to lif...
# 52867  I am in need of someone to search engine optim...
# 52907  We are seeking a German-speaking content write...
# 52917  We are seeking a skilled SEO/SEM specialist wh...
# 53018  So, I am developing a new business in the UAE ...
#
#                   published_date  is_hourly  hourly_low  hourly_high  \
# 5      2024-02-17 09:07:41+00:00       True   17.467895     41.60805
# 87     2024-02-18 04:34:44+00:00      False   17.467895     41.60805
# 142    2024-02-18 09:13:09+00:00       True   17.467895     41.60805
# 167    2024-02-19 00:41:41+00:00      False   17.467895     41.60805
# 266    2024-02-17 16:00:16+00:00       True   16.000000     18.00000
# ...                          ...        ...         ...          ...
# 52743  2024-02-16 07:33:42+00:00       True    5.000000     10.00000
# 52867  2024-02-20 03:31:34+00:00       True   17.467895     41.60805
# 52907  2024-02-23 14:02:57+00:00      False   17.467895     41.60805
# 52917  2024-02-23 10:26:08+00:00       True   50.000000    100.00000
# 53018  2024-02-19 10:20:02+00:00      False   17.467895     41.60805
#
#            budget         country
# 5      746.263521        Portugal
# 87     100.000000   United States
# 142    746.263521          Israel
# 167    400.000000          Canada
# 266    746.263521  United Kingdom
# ...           ...             ...
# 52743  746.263521   United States
# 52867  746.263521   United States
# 52907   65.000000         Hungary
# 52917  746.263521           Italy
# 53018  150.000000        Pakistan
#
# [987 rows x 9 columns]

# %%
#making them simple 
# Replace cells containing 'SEO' with 'SEO' and remove extra strings

df['title'] = df['title'].str.replace('.*SEO.*', 'SEO', regex=True)

# %%
df["title"].value_counts()
# Out:
# SEO                                                                             985
# Virtual Assistant                                                                99
# Social Media Manager                                                             89
# Graphic Designer                                                                 63
# Simple copy and paste data from a webpage into excel                             49
#                                                                                ...
# Creative video editor and graphics designer for a global brand                    1
# Athletic Wear Production Manager                                                  1
# Ghostwriter with experience in tech industry to write series of white papers      1
# Presentation Template for Nonprofit organization                                  1
# Make room and price modifications to Hotel booking plugin                         1
# Name: title, Length: 45174, dtype: int64

# %%
df[df["title"].str.contains("Graphic Designer")]
# Out:
#                                                    title  \
# 173                                     Graphic Designer
# 263          Graphic Designer - Needed for logo creation
# 587     Graphic Designer for Bauernaufstand Vektorgrafik
# 588      German-speaking T-Shirt Vector Graphic Designer
# 613    Graphic Designers Needed for Beverage Company ...
# ...                                                  ...
# 52801  Creative Graphic Designer for Innovative Projects
# 52851  Graphic Designer to create printable inserts f...
# 52978  Creative Graphic Designer for Web Development ...
# 53003  Graphic Designer for Amazon Listing and A+ EBC...
# 53034  Junior Graphic Designer needed to resize Photo...
#
#                                                     link  \
# 173    https://www.upwork.com/jobs/Graphic-Designer_%...
# 263    https://www.upwork.com/jobs/Graphic-Designer-N...
# 587    https://www.upwork.com/jobs/Graphic-Designer-f...
# 588    https://www.upwork.com/jobs/German-speaking-Sh...
# 613    https://www.upwork.com/jobs/Graphic-Designers-...
# ...                                                  ...
# 52801  https://www.upwork.com/jobs/Creative-Graphic-D...
# 52851  https://www.upwork.com/jobs/Graphic-Designer-c...
# 52978  https://www.upwork.com/jobs/Creative-Graphic-D...
# 53003  https://www.upwork.com/jobs/Graphic-Designer-f...
# 53034  https://www.upwork.com/jobs/Junior-Graphic-Des...
#
#                                              description  \
# 173    We are seeking a talented Designer to help wit...
# 263    Hello Graphic Designers!I am a small business ...
# 587    We are looking for a skilled graphic designer ...
# 588    We are in need of a talented graphic designer ...
# 613    We are looking for a team of graphic designers...
# ...                                                  ...
# 52801  Are you a passionate and versatile Graphic Des...
# 52851  We own a liquor and cigar shop in central Kans...
# 52978  We are a newly established web development com...
# 53003  Job Description:Introduction:We are looking fo...
# 53034  I need to resize Artboards in Adobe Photoshop....
#
#                   published_date  is_hourly  hourly_low  hourly_high  \
# 173    2024-02-19 00:39:10+00:00      False   17.467895     41.60805
# 263    2024-02-17 16:00:33+00:00      False   17.467895     41.60805
# 587    2024-02-18 14:12:37+00:00      False   17.467895     41.60805
# 588    2024-02-18 14:12:36+00:00      False   17.467895     41.60805
# 613    2024-02-14 19:44:12+00:00       True   15.000000    100.00000
# ...                          ...        ...         ...          ...
# 52801  2024-02-16 14:44:16+00:00       True   50.000000    150.00000
# 52851  2024-02-14 16:27:14+00:00       True   35.000000     50.00000
# 52978  2024-02-14 18:45:26+00:00       True   50.000000    150.00000
# 53003  2024-02-19 10:24:45+00:00      False   17.467895     41.60805
# 53034  2024-02-16 17:30:29+00:00       True    8.000000     16.00000
#
#            budget        country
# 173    150.000000      Australia
# 263    150.000000  United States
# 587     35.000000        Germany
# 588     35.000000        Germany
# 613    746.263521  United States
# ...           ...            ...
# 52801  746.263521       Pakistan
# 52851  746.263521  United States
# 52978  746.263521       Pakistan
# 53003  250.000000        Romania
# 53034  746.263521   South Africa
#
# [583 rows x 9 columns]

# %%
df['title'] = df['title'].str.replace('.*Graphic Designer.*', 'Graphic Designer', regex=True)
df['title'] = df['title'].str.replace('.*Graphic Design.*', 'Graphic Designer', regex=True)
df['title'] = df['title'].str.replace('.*Logo Design.*', 'Graphic Designer', regex=True)
df['title'] = df['title'].str.replace('.*Logo design.*', 'Graphic Designer', regex=True)
df["title"].value_counts().to_csv('title_counts.csv',header=True)

# %%
df['title'] = df['title'].str.replace('.*design.*', 'Graphic Designer', regex=True)
df['title'] = df['title'].str.replace('.*Design.*', 'Graphic Designer', regex=True)
df['title'] = df['title'].str.replace('.*Logo.*', 'Graphic Designer', regex=True)
df['title'] = df['title'].str.replace('.*logo.*', 'Graphic Designer', regex=True)
df['title'] = df['title'].str.replace('.*LOGO.*', 'Graphic Designer', regex=True)

# %%
df["title"].value_counts().to_csv('title_counts.csv',header=True)
